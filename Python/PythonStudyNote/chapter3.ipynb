# %%
# 주석은 이렇게 작성
print("제대로 적용이 된건가")
# 화면에 노출이 안됨
# Out:
# 제대로 적용이 된건가

# %%
"""
여기선 적용이 안되는듯
"""
# vscode에서는 적용될거라고 하셨다.
# Out:
# '\n여기선 적용이 안되는듯\n'

# %%
for 동물 in ("토끼", "사자", "푸바오", "호랑이"):
        print(동물)
        print("보러갈래요?")
# Out:
# 토끼
# 보러갈래요?
# 사자
# 보러갈래요?
# 푸바오
# 보러갈래요?
# 호랑이
# 보러갈래요?

# %%
for 동물 in ("토끼", "사자", "푸바오", "호랑이"):
    print(동물)
     print("보러갈래요?")

# 들여쓰기는 맞춰서 사용
# Out:
# 토끼
# 보러갈래요?
# 사자
# 보러갈래요?
# 푸바오
# 보러갈래요?
# 호랑이
# 보러갈래요?
